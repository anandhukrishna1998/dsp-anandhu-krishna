# %%
import numpy as np
import matplotlib.pyplot as plt


array = np.random.randint(0, 100, size=(10, 3))


print(array)


plt.figure(figsize=(8, 6))
plt.imshow(array, cmap='viridis', aspect='auto')
plt.colorbar(label='Value')
plt.title('Visualization of random array')
plt.xlabel('column index')
plt.ylabel('row index')
plt.show()
# Out:
# [[52 49  7]
#  [74 39 41]
#  [22 55 26]
#  [79 91 88]
#  [98 34 35]
#  [37 65  9]
#  [ 3 90 57]
#  [93 36 29]
#  [21 77 28]
#  [81 79 84]]
